# %% [markdown]
# 3. Manejo de cadenas

# %%
cadena = "Universidadd nacional tecnologica de lima sur"
#012334......
#Universidadd nacional trecnologica de lima sur
#012334......
#                             -2-1

# %%
cadena[5]
# Out:
# 'r'

# %%
cadena[-5]
# Out:
# 'a'

# %%
cadena[21]
# Out:
# ' '

# %%
cadena[-23]
# Out:
# 't'

# %%
cadena[3:8]
# Out:
# 'versi'

# %%
# para saber el tamaño de duna cadena utilizamos len()

len(cadena)
# Out:
# 45

# %%
#Para mostrar una cadena en mayuscula utilizamos upper()
cadena.upper()
# Out:
# 'UNIVERSIDADD NACIONAL TECNOLOGICA DE LIMA SUR'

# %%
cadena
# Out:
# 'Universidadd nacional tecnologica de lima sur'

# %%
#Para mostrar una cadena en minuscula utiliozamos lower()
cadena.lower()
# Out:
# 'universidadd nacional tecnologica de lima sur'

# %%
#Generar una lista a partir de una cadena .split()
cadena.split()
# Out:
# ['Universidadd', 'nacional', 'tecnologica', 'de', 'lima', 'sur']

# %%
#Generar una lista utilizando un criteriuo de sepaarcion a partir
# en este caso vamos a generar una lista de toda la cadena,
# utilizando como criterio de separacion la letra A
cadena.split("U")
# Out:
# ['', 'niversidadd nacional tecnologica de lima sur']

# %%
#concatenar con +
nombre = "Facundo Moreno"
print("Buenas tardes " + nombre)
# Out:
# Buenas tardes Facundo Moreno

# %%
#utilizando el .format()
nombre = "Facundo Moreno"
edad = 10
print("Hola {} ya se que tienes {} años".format(nombre,edad))
# Out:
# Hola Facundo Moreno ya se que tienes 10 años

# %%
#dar formato a numeros con muchos decimales
resultado = 10/3
print(f"10/3 es = (resulatdo)")
